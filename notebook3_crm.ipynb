# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('blockshield_crm.csv')
print('Rows loaded:', len(df))
# Out:
# Rows loaded: 200

# %% [markdown]
# ### Mean Values

# %%
print('Variable 7 — Avg Client Satisfaction Score:', round(df['satisfaction_score'].mean(), 2), '/ 10')
print('             Avg Renewal Probability       :', round(df['renewal_probability'].mean() * 100, 1), '%')
print('             Avg Customer Lifetime Value   :', round(df['clv_lakhs'].mean(), 2), 'Rs. Lakhs')
# Out:
# Variable 7 — Avg Client Satisfaction Score: 8.35 / 10
#              Avg Renewal Probability       : 80.2 %
#              Avg Customer Lifetime Value   : 8.01 Rs. Lakhs

# %% [markdown]
# ### Graph — Client Satisfaction Score

# %%
plt.figure(figsize=(8, 4))
plt.hist(df['satisfaction_score'], bins=15, color='steelblue', edgecolor='white')
plt.axvline(df['satisfaction_score'].mean(), color='red', linestyle='--',
            label=f'Mean: {df["satisfaction_score"].mean():.2f}')
plt.axvline(8.5, color='orange', linestyle='--', label='Target: 8.5')
plt.title('Client Satisfaction Score Distribution')
plt.xlabel('Score (1-10)')
plt.ylabel('Number of Clients')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Graph — Renewal Probability

# %%
plt.figure(figsize=(8, 4))
plt.hist(df['renewal_probability'], bins=15, color='green', edgecolor='white', alpha=0.8)
plt.axvline(df['renewal_probability'].mean(), color='red', linestyle='--',
            label=f'Mean: {df["renewal_probability"].mean()*100:.1f}%')
plt.title('Client Renewal Probability Distribution')
plt.xlabel('Renewal Probability')
plt.ylabel('Number of Clients')
plt.legend()
plt.tight_layout()
plt.show()
